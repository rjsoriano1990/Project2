# %%
# importing depencies
import os 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Establishing the path to our first dataset mouse_metadata_df

csv_file = os.path.join("COVID-19_Vaccinations_in_the_United_States_Jurisdiction.csv")

US_Cov19_df = pd.read_csv(csv_file,low_memory=False)

US_Cov19_df
# Out:
#              Date  MMWR_week Location Distributed Distributed_Janssen  \
# 0      10/28/2021         43       MO   8,411,045             347,900
# 1      10/28/2021         43       UT   4,355,130             198,100
# 2      10/28/2021         43       MT   1,464,145              87,700
# 3      10/28/2021         43      VA2   6,744,640             559,700
# 4      10/28/2021         43       SD   1,324,315              72,100
# ...           ...        ...      ...         ...                 ...
# 20691  12/13/2020         51       GU       3,900                   0
# 20692  12/13/2020         51       AS       3,900                   0
# 20693  12/13/2020         51       MP       4,875                   0
# 20694  12/13/2020         51       VI         975                   0
# 20695  12/13/2020         51      LTC           0                   0
#
#       Distributed_Moderna Distributed_Pfizer Distributed_Unk_Manuf  \
# 0               3,293,640          4,769,505                     0
# 1               1,611,740          2,545,290                     0
# 2                 619,680            756,765                     0
# 3               3,192,860          2,992,080                     0
# 4                 553,500            698,715                     0
# ...                   ...                ...                   ...
# 20691                   0                  0                     0
# 20692                   0                  0                     0
# 20693                   0                  0                     0
# 20694                   0                  0                     0
# 20695                   0                  0                     0
#
#       Dist_Per_100K Distributed_Per_100k_12Plus  ... Additional_Doses_18Plus  \
# 0           137,045                     160,647  ...                282921.0
# 1           135,845                     168,005  ...                105335.0
# 2           136,992                     159,563  ...                 64353.0
# 3                 0                           0  ...                249681.0
# 4           149,698                     179,422  ...                 43633.0
# ...             ...                         ...  ...                     ...
# 20691         2,353                           0  ...                     0.0
# 20692         7,003                           0  ...                     0.0
# 20693         8,570                           0  ...                     0.0
# 20694           931                           0  ...                     0.0
# 20695             0                           0  ...                     0.0
#
#       Additional_Doses_18Plus_Vax_Pct Additional_Doses_50Plus  \
# 0                                 9.9                237790.0
# 1                                 6.8                 85882.0
# 2                                12.6                 54339.0
# 3                                 8.7                241856.0
# 4                                10.0                 37177.0
# ...                               ...                     ...
# 20691                             0.0                     0.0
# 20692                             0.0                     0.0
# 20693                             0.0                     0.0
# 20694                             0.0                     0.0
# 20695                             0.0                     0.0
#
#       Additional_Doses_50Plus_Vax_Pct Additional_Doses_65Plus  \
# 0                                14.6                183133.0
# 1                                13.1                 68732.0
# 2                                18.1                 42280.0
# 3                                10.7                200470.0
# 4                                14.9                 28523.0
# ...                               ...                     ...
# 20691                             0.0                     0.0
# 20692                             0.0                     0.0
# 20693                             0.0                     0.0
# 20694                             0.0                     0.0
# 20695                             0.0                     0.0
#
#       Additional_Doses_65Plus_Vax_Pct Additional_Doses_Moderna  \
# 0                                21.5                  40004.0
# 1                                21.9                   9627.0
# 2                                25.0                  11460.0
# 3                                13.6                  45860.0
# 4                                21.4                   6692.0
# ...                               ...                      ...
# 20691                             0.0                      0.0
# 20692                             0.0                      0.0
# 20693                             0.0                      0.0
# 20694                             0.0                      0.0
# 20695                             0.0                      0.0
#
#       Additional_Doses_Pfizer Additional_Doses_Janssen  \
# 0                    242897.0                    384.0
# 1                     95964.0                     88.0
# 2                     52770.0                    177.0
# 3                    203639.0                    167.0
# 4                     36881.0                     88.0
# ...                       ...                      ...
# 20691                     0.0                      0.0
# 20692                     0.0                      0.0
# 20693                     0.0                      0.0
# 20694                     0.0                      0.0
# 20695                     0.0                      0.0
#
#       Additional_Doses_Unk_Manuf
# 0                           21.0
# 1                           14.0
# 2                           48.0
# 3                           16.0
# 4                            0.0
# ...                          ...
# 20691                        0.0
# 20692                        0.0
# 20693                        0.0
# 20694                        0.0
# 20695                        0.0
#
# [20696 rows x 69 columns]

# %%
US_Cov19_df.columns.tolist()
# Out:
# ['Date',
#  'MMWR_week',
#  'Location',
#  'Distributed',
#  'Distributed_Janssen',
#  'Distributed_Moderna',
#  'Distributed_Pfizer',
#  'Distributed_Unk_Manuf',
#  'Dist_Per_100K',
#  'Distributed_Per_100k_12Plus',
#  'Distributed_Per_100k_18Plus',
#  'Distributed_Per_100k_65Plus',
#  'Administered',
#  'Administered_12Plus',
#  'Administered_18Plus',
#  'Administered_65Plus',
#  'Administered_Janssen',
#  'Administered_Moderna',
#  'Administered_Pfizer',
#  'Administered_Unk_Manuf',
#  'Admin_Per_100K',
#  'Admin_Per_100k_12Plus',
#  'Admin_Per_100k_18Plus',
#  'Admin_Per_100k_65Plus',
#  'Recip_Administered',
#  'Administered_Dose1_Recip',
#  'Administered_Dose1_Pop_Pct',
#  'Administered_Dose1_Recip_12Plus',
#  'Administered_Dose1_Recip_12PlusPop_Pct',
#  'Administered_Dose1_Recip_18Plus',
#  'Administered_Dose1_Recip_18PlusPop_Pct',
#  'Administered_Dose1_Recip_65Plus',
#  'Administered_Dose1_Recip_65PlusPop_Pct',
#  'Series_Complete_Yes',
#  'Series_Complete_Pop_Pct',
#  'Series_Complete_12Plus',
#  'Series_Complete_12PlusPop_Pct',
#  'Series_Complete_18Plus',
#  'Series_Complete_18PlusPop_Pct',
#  'Series_Complete_65Plus',
#  'Series_Complete_65PlusPop_Pct',
#  'Series_Complete_Janssen',
#  'Series_Complete_Moderna',
#  'Series_Complete_Pfizer',
#  'Series_Complete_Unk_Manuf',
#  'Series_Complete_Janssen_12Plus',
#  'Series_Complete_Moderna_12Plus',
#  'Series_Complete_Pfizer_12Plus',
#  'Series_Complete_Unk_Manuf_12Plus',
#  'Series_Complete_Janssen_18Plus',
#  'Series_Complete_Moderna_18Plus',
#  'Series_Complete_Pfizer_18Plus',
#  'Series_Complete_Unk_Manuf_18Plus',
#  'Series_Complete_Janssen_65Plus',
#  'Series_Complete_Moderna_65Plus',
#  'Series_Complete_Pfizer_65Plus',
#  'Series_Complete_Unk_Manuf_65Plus',
#  'Additional_Doses',
#  'Additional_Doses_Vax_Pct',
#  'Additional_Doses_18Plus',
#  'Additional_Doses_18Plus_Vax_Pct',
#  'Additional_Doses_50Plus',
#  'Additional_Doses_50Plus_Vax_Pct',
#  'Additional_Doses_65Plus',
#  'Additional_Doses_65Plus_Vax_Pct',
#  'Additional_Doses_Moderna',
#  'Additional_Doses_Pfizer',
#  'Additional_Doses_Janssen',
#  'Additional_Doses_Unk_Manuf']

# %%
#clean_US_Cov19_df = US_Cov19_df.dropna(how="any")

#clean_US_Cov19_df

# %%
# Selecting columns of interets

New_US_Cov19_df = US_Cov19_df[['Date',
 'Location',
 'Distributed',
 'Distributed_Janssen',
 'Distributed_Moderna',
 'Distributed_Pfizer','Dist_Per_100K','Administered','Administered_Janssen',
 'Administered_Moderna',
 'Administered_Pfizer','Recip_Administered',
 'Administered_Dose1_Recip',
 'Administered_Dose1_Pop_Pct']].copy()

New_US_Cov19_df
# Out:
#              Date Location Distributed Distributed_Janssen  \
# 0      10/28/2021       MO   8,411,045             347,900
# 1      10/28/2021       UT   4,355,130             198,100
# 2      10/28/2021       MT   1,464,145              87,700
# 3      10/28/2021      VA2   6,744,640             559,700
# 4      10/28/2021       SD   1,324,315              72,100
# ...           ...      ...         ...                 ...
# 20691  12/13/2020       GU       3,900                   0
# 20692  12/13/2020       AS       3,900                   0
# 20693  12/13/2020       MP       4,875                   0
# 20694  12/13/2020       VI         975                   0
# 20695  12/13/2020      LTC           0                   0
#
#       Distributed_Moderna Distributed_Pfizer Dist_Per_100K Administered  \
# 0               3,293,640          4,769,505       137,045    6,724,837
# 1               1,611,740          2,545,290       135,845    3,664,969
# 2                 619,680            756,765       136,992    1,178,365
# 3               3,192,860          2,992,080             0    5,974,228
# 4                 553,500            698,715       149,698    1,016,852
# ...                   ...                ...           ...          ...
# 20691                   0                  0         2,353            0
# 20692                   0                  0         7,003            0
# 20693                   0                  0         8,570            0
# 20694                   0                  0           931            0
# 20695                   0                  0             0            0
#
#       Administered_Janssen Administered_Moderna Administered_Pfizer  \
# 0                  212,413            2,362,370           4,147,810
# 1                  150,795            1,320,420           2,193,452
# 2                   49,225              485,118             642,922
# 3                  219,925            2,951,030           2,802,896
# 4                   32,924              393,188             590,614
# ...                    ...                  ...                 ...
# 20691                    0                    0                   0
# 20692                    0                    0                   0
# 20693                    0                    0                   0
# 20694                    0                    0                   0
# 20695                    0                    0                   0
#
#       Recip_Administered Administered_Dose1_Recip  Administered_Dose1_Pop_Pct
# 0              6,643,179                3,476,255                        56.6
# 1              3,632,701                1,951,501                        60.9
# 2              1,176,024                  605,903                        56.7
# 3              5,974,228                3,077,985                         0.0
# 4              1,022,877                  545,835                        61.7
# ...                  ...                      ...                         ...
# 20691                  0                        0                         0.0
# 20692                  0                        0                         0.0
# 20693                  0                        0                         0.0
# 20694                  0                        0                         0.0
# 20695                  0                        0                         0.0
#
# [20696 rows x 14 columns]

# %%
# converting the date column format to_date()

New_US_Cov19_df["Date"] = pd.to_datetime(New_US_Cov19_df["Date"])

New_US_Cov19_df
# Out:
#             Date Location Distributed Distributed_Janssen Distributed_Moderna  \
# 0     2021-10-28       MO   8,411,045             347,900           3,293,640
# 1     2021-10-28       UT   4,355,130             198,100           1,611,740
# 2     2021-10-28       MT   1,464,145              87,700             619,680
# 3     2021-10-28      VA2   6,744,640             559,700           3,192,860
# 4     2021-10-28       SD   1,324,315              72,100             553,500
# ...          ...      ...         ...                 ...                 ...
# 20691 2020-12-13       GU       3,900                   0                   0
# 20692 2020-12-13       AS       3,900                   0                   0
# 20693 2020-12-13       MP       4,875                   0                   0
# 20694 2020-12-13       VI         975                   0                   0
# 20695 2020-12-13      LTC           0                   0                   0
#
#       Distributed_Pfizer Dist_Per_100K Administered Administered_Janssen  \
# 0              4,769,505       137,045    6,724,837              212,413
# 1              2,545,290       135,845    3,664,969              150,795
# 2                756,765       136,992    1,178,365               49,225
# 3              2,992,080             0    5,974,228              219,925
# 4                698,715       149,698    1,016,852               32,924
# ...                  ...           ...          ...                  ...
# 20691                  0         2,353            0                    0
# 20692                  0         7,003            0                    0
# 20693                  0         8,570            0                    0
# 20694                  0           931            0                    0
# 20695                  0             0            0                    0
#
#       Administered_Moderna Administered_Pfizer Recip_Administered  \
# 0                2,362,370           4,147,810          6,643,179
# 1                1,320,420           2,193,452          3,632,701
# 2                  485,118             642,922          1,176,024
# 3                2,951,030           2,802,896          5,974,228
# 4                  393,188             590,614          1,022,877
# ...                    ...                 ...                ...
# 20691                    0                   0                  0
# 20692                    0                   0                  0
# 20693                    0                   0                  0
# 20694                    0                   0                  0
# 20695                    0                   0                  0
#
#       Administered_Dose1_Recip  Administered_Dose1_Pop_Pct
# 0                    3,476,255                        56.6
# 1                    1,951,501                        60.9
# 2                      605,903                        56.7
# 3                    3,077,985                         0.0
# 4                      545,835                        61.7
# ...                        ...                         ...
# 20691                        0                         0.0
# 20692                        0                         0.0
# 20693                        0                         0.0
# 20694                        0                         0.0
# 20695                        0                         0.0
#
# [20696 rows x 14 columns]

# %%
# Selecting covid-19 data for the 50 states in the Us

filter_New_US_Cov19_df = New_US_Cov19_df.loc[New_US_Cov19_df ['Location'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

filter_New_US_Cov19_df
# Out:
#             Date Location Distributed Distributed_Janssen Distributed_Moderna  \
# 0     2021-10-28       MO   8,411,045             347,900           3,293,640
# 1     2021-10-28       UT   4,355,130             198,100           1,611,740
# 2     2021-10-28       MT   1,464,145              87,700             619,680
# 4     2021-10-28       SD   1,324,315              72,100             553,500
# 5     2021-10-28       VT   1,144,350              63,900             477,900
# ...          ...      ...         ...                 ...                 ...
# 20684 2020-12-14       MI       3,900                   0                   0
# 20685 2020-12-14       MN       1,950                   0                   0
# 20686 2020-12-14       OK      17,550                   0                   0
# 20688 2020-12-14       VT       1,950                   0                   0
# 20689 2020-12-14       WV      10,725                   0                   0
#
#       Distributed_Pfizer Dist_Per_100K Administered Administered_Janssen  \
# 0              4,769,505       137,045    6,724,837              212,413
# 1              2,545,290       135,845    3,664,969              150,795
# 2                756,765       136,992    1,178,365               49,225
# 4                698,715       149,698    1,016,852               32,924
# 5                602,550       183,393      964,013               44,952
# ...                  ...           ...          ...                  ...
# 20684                  0            39            0                    0
# 20685                  0            35            0                    0
# 20686                  0           444            0                    0
# 20688                  0           313            0                    0
# 20689                  0           598           29                    0
#
#       Administered_Moderna Administered_Pfizer Recip_Administered  \
# 0                2,362,370           4,147,810          6,643,179
# 1                1,320,420           2,193,452          3,632,701
# 2                  485,118             642,922          1,176,024
# 4                  393,188             590,614          1,022,877
# 5                  366,732             551,498            950,864
# ...                    ...                 ...                ...
# 20684                    0                   0                  0
# 20685                    0                   0                  0
# 20686                    0                   0                  0
# 20688                    0                   0                  0
# 20689                    0                  29                  0
#
#       Administered_Dose1_Recip  Administered_Dose1_Pop_Pct
# 0                    3,476,255                        56.6
# 1                    1,951,501                        60.9
# 2                      605,903                        56.7
# 4                      545,835                        61.7
# 5                      495,479                        79.4
# ...                        ...                         ...
# 20684                        0                         0.0
# 20685                        0                         0.0
# 20686                        0                         0.0
# 20688                        0                         0.0
# 20689                        0                         0.0
#
# [15950 rows x 14 columns]

# %%
New_US_Cov19_df.to_csv('test.csv', index=False)

# %%
renamed_US_Cov19_df = filter_New_US_Cov19_df.rename(columns={'Date':"submission_date",
'Location':"state",
 'Distributed':"distributed",
 'Distributed_Janssen':"distributed_janssen",
 'Distributed_Moderna':"distributed_moderna",
 'Distributed_Pfizer':"distributed_pfizer",'Dist_Per_100K':"dist_per_100K",'Administered':"administered",'Administered_Janssen':"administered_janssen",
 'Administered_Moderna':"administered_moderna",
 'Administered_Pfizer':"administered_pfizer",'Recip_Administered':"recip_administered",
 'Administered_Dose1_Recip':"administered_dose1_recip",
 'Administered_Dose1_Pop_Pct':"administered_dose1_pop_pct"})

renamed_US_Cov19_df
# Out:
#       submission_date state distributed distributed_janssen  \
# 0          2021-10-28    MO   8,411,045             347,900
# 1          2021-10-28    UT   4,355,130             198,100
# 2          2021-10-28    MT   1,464,145              87,700
# 4          2021-10-28    SD   1,324,315              72,100
# 5          2021-10-28    VT   1,144,350              63,900
# ...               ...   ...         ...                 ...
# 20684      2020-12-14    MI       3,900                   0
# 20685      2020-12-14    MN       1,950                   0
# 20686      2020-12-14    OK      17,550                   0
# 20688      2020-12-14    VT       1,950                   0
# 20689      2020-12-14    WV      10,725                   0
#
#       distributed_moderna distributed_pfizer dist_per_100K administered  \
# 0               3,293,640          4,769,505       137,045    6,724,837
# 1               1,611,740          2,545,290       135,845    3,664,969
# 2                 619,680            756,765       136,992    1,178,365
# 4                 553,500            698,715       149,698    1,016,852
# 5                 477,900            602,550       183,393      964,013
# ...                   ...                ...           ...          ...
# 20684                   0                  0            39            0
# 20685                   0                  0            35            0
# 20686                   0                  0           444            0
# 20688                   0                  0           313            0
# 20689                   0                  0           598           29
#
#       administered_janssen administered_moderna administered_pfizer  \
# 0                  212,413            2,362,370           4,147,810
# 1                  150,795            1,320,420           2,193,452
# 2                   49,225              485,118             642,922
# 4                   32,924              393,188             590,614
# 5                   44,952              366,732             551,498
# ...                    ...                  ...                 ...
# 20684                    0                    0                   0
# 20685                    0                    0                   0
# 20686                    0                    0                   0
# 20688                    0                    0                   0
# 20689                    0                    0                  29
#
#       recip_administered administered_dose1_recip  administered_dose1_pop_pct
# 0              6,643,179                3,476,255                        56.6
# 1              3,632,701                1,951,501                        60.9
# 2              1,176,024                  605,903                        56.7
# 4              1,022,877                  545,835                        61.7
# 5                950,864                  495,479                        79.4
# ...                  ...                      ...                         ...
# 20684                  0                        0                         0.0
# 20685                  0                        0                         0.0
# 20686                  0                        0                         0.0
# 20688                  0                        0                         0.0
# 20689                  0                        0                         0.0
#
# [15950 rows x 14 columns]

# %%
final_df = renamed_US_Cov19_df.sort_values(by=['state', 'submission_date'])

# %%
final_df
# Out:
#       submission_date state distributed distributed_janssen  \
# 20638      2020-12-14    AK       4,875                   0
# 20615      2020-12-15    AK      12,675                   0
# 20562      2020-12-16    AK      26,325                   0
# 20449      2020-12-17    AK      26,325                   0
# 20393      2020-12-18    AK      26,325                   0
# ...               ...   ...         ...                 ...
# 292        2021-10-24    WY     716,185              38,800
# 228        2021-10-25    WY     716,045              38,800
# 180        2021-10-26    WY     717,185              39,100
# 125        2021-10-27    WY     723,265              39,800
# 18         2021-10-28    WY     731,765              40,400
#
#       distributed_moderna distributed_pfizer dist_per_100K administered  \
# 20638                   0                  0           666            0
# 20615                   0                  0         1,733            0
# 20562                   0                  0         3,599            0
# 20449                   0                  0         3,599            2
# 20393                   0                  0         3,599            2
# ...                   ...                ...           ...          ...
# 292               324,600            352,785       123,745      557,460
# 228               324,460            352,785       123,721      557,481
# 180               325,300            352,785       123,918      561,249
# 125               328,340            355,125       124,968      563,122
# 18                333,900            357,465       126,437      565,644
#
#       administered_janssen administered_moderna administered_pfizer  \
# 20638                    0                    0                   0
# 20615                    0                    0                   0
# 20562                    0                    0                   0
# 20449                    0                    0                   2
# 20393                    0                    0                   2
# ...                    ...                  ...                 ...
# 292                 24,395              241,106             291,447
# 228                 24,395              241,106             291,468
# 180                 24,475              242,586             293,675
# 125                 24,529              243,457             294,621
# 18                  24,586              244,720             295,821
#
#       recip_administered administered_dose1_recip  administered_dose1_pop_pct
# 20638                  0                        0                         0.0
# 20615                  0                        0                         0.0
# 20562                  0                        0                         0.0
# 20449                  0                        0                         0.0
# 20393                  0                        0                         0.0
# ...                  ...                      ...                         ...
# 292              552,547                  291,267                        50.3
# 228              552,635                  291,315                        50.3
# 180              556,329                  292,154                        50.5
# 125              558,285                  292,654                        50.6
# 18               560,909                  293,260                        50.7
#
# [15950 rows x 14 columns]

# %%
final_df.columns.tolist()
# Out:
# ['submission_date',
#  'state',
#  'distributed',
#  'distributed_janssen',
#  'distributed_moderna',
#  'distributed_pfizer',
#  'dist_per_100K',
#  'administered',
#  'administered_janssen',
#  'administered_moderna',
#  'administered_pfizer',
#  'recip_administered',
#  'administered_dose1_recip',
#  'administered_dose1_pop_pct']
